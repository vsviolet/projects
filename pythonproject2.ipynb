# %%
# import libraries 

import pandas as pd
import seaborn as sns
import numpy as np

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')
from matplotlib.pyplot import figure


df = pd.read_csv(r'/Users/violet/US_Accidents_Dec21_updated.csv')

# %%
df.head()
# Out:
#     ID  Severity           Start_Time             End_Time  Start_Lat  \
# 0  A-1         3  2016-02-08 00:37:08  2016-02-08 06:37:08  40.108910
# 1  A-2         2  2016-02-08 05:56:20  2016-02-08 11:56:20  39.865420
# 2  A-3         2  2016-02-08 06:15:39  2016-02-08 12:15:39  39.102660
# 3  A-4         2  2016-02-08 06:51:45  2016-02-08 12:51:45  41.062130
# 4  A-5         3  2016-02-08 07:53:43  2016-02-08 13:53:43  39.172393
#
#    Start_Lng    End_Lat    End_Lng  Distance(mi)  \
# 0 -83.092860  40.112060 -83.031870         3.230
# 1 -84.062800  39.865010 -84.048730         0.747
# 2 -84.524680  39.102090 -84.523960         0.055
# 3 -81.537840  41.062170 -81.535470         0.123
# 4 -84.492792  39.170476 -84.501798         0.500
#
#                                          Description  ...  Roundabout Station  \
# 0  Between Sawmill Rd/Exit 20 and OH-315/Olentang...  ...       False   False
# 1                 At OH-4/OH-235/Exit 41 - Accident.  ...       False   False
# ...

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Number', 'Street',
#        'Side', 'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2845342 entries, 0 to 2845341
# Data columns (total 47 columns):
#  #   Column                 Dtype
# ---  ------                 -----
#  0   ID                     object
#  1   Severity               int64
#  2   Start_Time             object
#  3   End_Time               object
#  4   Start_Lat              float64
#  5   Start_Lng              float64
#  6   End_Lat                float64
#  7   End_Lng                float64
#  8   Distance(mi)           float64
#  9   Description            object
#  10  Number                 float64
#  11  Street                 object
#  12  Side                   object
#  13  City                   object
#  14  County                 object
#  15  State                  object
#  16  Zipcode                object
#  17  Country                object
#  18  Timezone               object
#  19  Airport_Code           object
#  20  Weather_Timestamp      object
# ...

# %%
df.describe()
# Out:
#            Severity     Start_Lat     Start_Lng       End_Lat       End_Lng  \
# count  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06  2.845342e+06
# mean   2.137572e+00  3.624520e+01 -9.711463e+01  3.624532e+01 -9.711439e+01
# std    4.787216e-01  5.363797e+00  1.831782e+01  5.363873e+00  1.831763e+01
# min    1.000000e+00  2.456603e+01 -1.245481e+02  2.456601e+01 -1.245457e+02
# 25%    2.000000e+00  3.344517e+01 -1.180331e+02  3.344628e+01 -1.180333e+02
# 50%    2.000000e+00  3.609861e+01 -9.241808e+01  3.609799e+01 -9.241772e+01
# 75%    2.000000e+00  4.016024e+01 -8.037243e+01  4.016105e+01 -8.037338e+01
# max    4.000000e+00  4.900058e+01 -6.711317e+01  4.907500e+01 -6.710924e+01
#
#        Distance(mi)        Number  Temperature(F)  Wind_Chill(F)  \
# count  2.845342e+06  1.101431e+06    2.776068e+06   2.375699e+06
# mean   7.026779e-01  8.089408e+03    6.179356e+01   5.965823e+01
# std    1.560361e+00  1.836009e+04    1.862263e+01   2.116097e+01
# ...

# %% [markdown]
# ## Look for missing data

# %%
pct_missing = df.isna().sum().sort_values(ascending=False) / len(df)
pct_missing
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# Country                  0.000000e+00
# Junction                 0.000000e+00
# Start_Time               0.000000e+00
# End_Time                 0.000000e+00
# Start_Lat                0.000000e+00
# ...

# %%
pct_missing[pct_missing !=0]
# Out:
# Number                   6.129003e-01
# Precipitation(in)        1.931079e-01
# Wind_Chill(F)            1.650568e-01
# Wind_Speed(mph)          5.550967e-02
# Wind_Direction           2.592834e-02
# Humidity(%)              2.568830e-02
# Weather_Condition        2.482514e-02
# Visibility(mi)           2.479350e-02
# Temperature(F)           2.434646e-02
# Pressure(in)             2.080593e-02
# Weather_Timestamp        1.783125e-02
# Airport_Code             3.356011e-03
# Timezone                 1.285961e-03
# Nautical_Twilight        1.007612e-03
# Civil_Twilight           1.007612e-03
# Sunrise_Sunset           1.007612e-03
# Astronomical_Twilight    1.007612e-03
# Zipcode                  4.635647e-04
# City                     4.814887e-05
# Street                   7.029032e-07
# dtype: float64

# %%
pct_missing[pct_missing !=0].plot(kind='bar')
# Out:
# <AxesSubplot:>

# %%
#remove number column because over half the values are null 

df = df.drop('Number', axis=1)

# %%
#columns we'll analyze - city, start time, start Lat, start Lng, temperature, weather condition
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Street', 'Side',
#        'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# ### Some questions to ask while exploring the data
#
# 1. Are there more accidents in warmer or colder areas
#
# 2. Which states/cities/streets have most accidents
#
# 3. What times/days/months have the most accidents
#
# 4. Trend of accidents year over year

# %%
cities = df.City.unique()
len(cities)
# Out:
# 11682

# %%
cities_by_accident = df.City.value_counts()
cities_by_accident[:55]
# Out:
# Miami              106966
# Los Angeles         68956
# Orlando             54691
# Dallas              41979
# Houston             39448
# Charlotte           33152
# Sacramento          32559
# San Diego           26627
# Raleigh             22840
# Minneapolis         22768
# Portland            20944
# Nashville           20267
# Austin              18301
# Baton Rouge         18182
# Phoenix             17143
# Saint Paul          16869
# New Orleans         16251
# Atlanta             15622
# Jacksonville        14967
# Richmond            14349
# Tucson              13799
# San Jose            13377
# Riverside           13310
# Kansas City         13298
# Bakersfield         12044
# San Bernardino      11249
# Chicago             11188
# Tampa               10984
# Salt Lake City      10709
# Ontario             10538
# Anaheim             10502
# Hialeah             10398
# Fort Lauderdale     10345
# Oakland             10051
# Columbia             9885
# ...

# %%
cities_by_accident[:20].plot(kind='bar')
plt.title('Cities With Most Accidents')
# Out:
# Text(0.5, 1.0, 'Cities With Most Accidents')

# %%
high_accident_cities = cities_by_accident[cities_by_accident >= 1000]
low_accident_cities = cities_by_accident[cities_by_accident < 100]

# %%
len(high_accident_cities)
# Out:
# 496

# %%
len(cities)
# Out:
# 11682

# %%
len(high_accident_cities) / len(cities)
# Out:
# 0.04245848313644924

# %% [markdown]
# ####  4.2% of cities have more than 1,000 accidents

# %%
sns.histplot(high_accident_cities)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
 sns.histplot(cities_by_accident, log_scale = True)
# Out:
# <AxesSubplot:xlabel='City', ylabel='Count'>

# %%
accidents_per_state = df['State'].value_counts()
accidents_per_state
# Out:
# CA    795868
# FL    401388
# TX    149037
# OR    126341
# VA    113535
# NY    108049
# PA     99975
# MN     97185
# NC     91362
# SC     89216
# MD     65085
# AZ     56504
# NJ     52902
# TN     52613
# UT     49193
# LA     47232
# IL     47105
# MI     43843
# GA     40086
# WA     32554
# CT     29762
# MO     29633
# CO     25340
# OH     24409
# IN     20850
# AL     19322
# MT     15964
# AR     10935
# IA      9607
# DC      9133
# KS      9033
# OK      8806
# ID      8544
# WI      7896
# WV      7632
# KY      6638
# MA      6392
# NV      6197
# MS      5320
# DE      4842
# RI      4451
# NH      3866
# NE      3320
# NM      2370
# ND      2258
# ME      2193
# WY       990
# VT       365
# SD       201
# Name: State, dtype: int64

# %%
accidents_per_state[:20].plot(kind='barh')
plt.title('States With Most Accidents')
# Out:
# Text(0.5, 1.0, 'States With Most Accidents')

# %% [markdown]
# #### California has the most accidents by far

# %% [markdown]
# ## Check which streets have the most accidents

# %%
accident_streets = df['Street'].value_counts()
accident_streets[:20]
# Out:
# I-95 N     39853
# I-5 N      39402
# I-95 S     36425
# I-5 S      30229
# I-10 E     26164
# I-10 W     25298
# I-80 W     17545
# I-80 E     16873
# I-405 N    13708
# I-15 N     12675
# I-94 W     12378
# I-75 N     12086
# I-75 S     11962
# I-15 S     11921
# I-84 E     11677
# I-84 W     10658
# I-90 W     10164
# CA-99 N    10041
# I-94 E      9666
# I-70 E      9614
# Name: Street, dtype: int64

# %%
accident_streets[:20].plot(kind='bar')
plt.title('Streets Where Most Accidents Occur')
# Out:
# Text(0.5, 1.0, 'Streets Where Most Accidents Occur')

# %% [markdown]
# #### I-95 N has the most reported accidents

# %%
df.columns
# Out:
# Index(['ID', 'Severity', 'Start_Time', 'End_Time', 'Start_Lat', 'Start_Lng',
#        'End_Lat', 'End_Lng', 'Distance(mi)', 'Description', 'Street', 'Side',
#        'City', 'County', 'State', 'Zipcode', 'Country', 'Timezone',
#        'Airport_Code', 'Weather_Timestamp', 'Temperature(F)', 'Wind_Chill(F)',
#        'Humidity(%)', 'Pressure(in)', 'Visibility(mi)', 'Wind_Direction',
#        'Wind_Speed(mph)', 'Precipitation(in)', 'Weather_Condition', 'Amenity',
#        'Bump', 'Crossing', 'Give_Way', 'Junction', 'No_Exit', 'Railway',
#        'Roundabout', 'Station', 'Stop', 'Traffic_Calming', 'Traffic_Signal',
#        'Turning_Loop', 'Sunrise_Sunset', 'Civil_Twilight', 'Nautical_Twilight',
#        'Astronomical_Twilight'],
#       dtype='object')

# %% [markdown]
# ## Look at the times and days with most accidents

# %%
df.Start_Time = pd.to_datetime(df.Start_Time)
df.Start_Time
# Out:
# 0         2016-02-08 00:37:08
# 1         2016-02-08 05:56:20
# 2         2016-02-08 06:15:39
# 3         2016-02-08 06:51:45
# 4         2016-02-08 07:53:43
#                   ...
# 2845337   2019-08-23 18:03:25
# 2845338   2019-08-23 19:11:30
# 2845339   2019-08-23 19:00:21
# 2845340   2019-08-23 19:00:21
# 2845341   2019-08-23 18:52:06
# Name: Start_Time, Length: 2845342, dtype: datetime64[ns]

# %%
# Time of day where accidents are most common 

sns.histplot(df.Start_Time.dt.hour, bins=24)
# Out:
# <AxesSubplot:xlabel='Start_Time', ylabel='Count'>

# %% [markdown]
# #### Highest percentage of accidents happen between 4 and 6 pm. Likely because people are leaving work and rushing to get home

# %%
# Days of the week with most accidents

plt.figure(figsize=(10,5))
sns.histplot(df.Start_Time.dt.day_name())
plt.xlabel('Days of the week')
plt.title('Accidents During the Week')
# Out:
# Text(0.5, 1.0, 'Accidents During the Week')

# %% [markdown]
# #### More accidents during the weekdays than the weekends

# %%
# Check out when accidents occur on Sunday 

sundays_accidents = df.Start_Time[df.Start_Time.dt.day_name() == 'Sunday']
sns.histplot(sundays_accidents.dt.hour, bins=24)
# Out:
# <AxesSubplot:xlabel='Start_Time', ylabel='Count'>

# %% [markdown]
# #### Most Sunday accidents occur from noon to 8 pm.

# %%
# Monday accidents 

mondays_accidents = df.Start_Time[df.Start_Time.dt.day_name() == 'Monday']
sns.histplot(mondays_accidents.dt.hour, bins=24)
# Out:
# <AxesSubplot:xlabel='Start_Time', ylabel='Count'>

# %% [markdown]
# #### Most Monday accidents are in the morning around 7 am and from 3 to 5 pm

# %%
months_accidents = df.Start_Time.dt.month_name().value_counts()
months_accidents
# Out:
# December     473943
# November     360696
# October      299131
# September    241822
# June         226561
# January      198365
# February     194995
# May          181944
# August       178670
# April        171880
# July         159111
# March        158224
# Name: Start_Time, dtype: int64

# %%
plt.figure(figsize=(14,5))
sns.barplot(y=months_accidents, x=months_accidents.index)
plt.ylabel('Number of Accidents')
plt.title('Accidents Each Month')
# Out:
# Text(0.5, 1.0, 'Accidents Each Month')

# %% [markdown]
# #### Most accidents occur in December, November and October

# %%
# See monthly data for 2019 only 

df_2019 = df[df.Start_Time.dt.year == 2019]
sns.histplot(df_2019.Start_Time.dt.month, bins=12)
# Out:
# <AxesSubplot:xlabel='Start_Time', ylabel='Count'>

# %%
yearly_accidents = df.Start_Time.dt.year.value_counts()
yearly_accidents
# Out:
# 2021    1511745
# 2020     625864
# 2019     258615
# 2017     163918
# 2018     163176
# 2016     122024
# Name: Start_Time, dtype: int64

# %%
sns.lineplot(data = yearly_accidents)
plt.ylabel('Number of Accidents (in millions)')
plt.xlabel('Year')
# Out:
# Text(0.5, 0, 'Year')

# %% [markdown]
# #### Accidents have been increasing since 2016

# %%
# Weather conditions 

weather = df['Weather_Condition'].value_counts()
weather[:15]
# Out:
# Fair                1107194
# Mostly Cloudy        363959
# Cloudy               348767
# Partly Cloudy        249939
# Clear                173823
# Light Rain           128403
# Overcast              84882
# Scattered Clouds      45132
# Light Snow            43752
# Fog                   41226
# Haze                  36354
# Rain                  31044
# Fair / Windy          15195
# Heavy Rain            11824
# Smoke                  7200
# Name: Weather_Condition, dtype: int64

# %%
plt.figure(figsize=(20,5))
sns.barplot(y=weather[:15], x=weather[:15].index)
plt.ylabel('Number of Accidents')
plt.title('Weather condition vs Number of Accidents')
# Out:
# Text(0.5, 1.0, 'Weather condition vs Number of Accidents')

# %% [markdown]
# #### Strangly enough, most accidents happen when the weather is fair, meaning weather consition isn't as much of a factor as we might think

# %% [markdown]
# ## Start Latitude and Longitude

# %%
df.Start_Lat
# Out:
# 0          40.108910
# 1          39.865420
# 2          39.102660
# 3          41.062130
# 4          39.172393
#              ...
# 2845337    34.002480
# 2845338    32.766960
# 2845339    33.775450
# 2845340    33.992460
# 2845341    34.133930
# Name: Start_Lat, Length: 2845342, dtype: float64

# %%
df.Start_Lng
# Out:
# 0          -83.092860
# 1          -84.062800
# 2          -84.524680
# 3          -81.537840
# 4          -84.492792
#               ...
# 2845337   -117.379360
# 2845338   -117.148060
# 2845339   -117.847790
# 2845340   -118.403020
# 2845341   -117.230920
# Name: Start_Lng, Length: 2845342, dtype: float64

# %%
sample_df = df.sample(int(0.1 * len(df)))
sns.scatterplot(x=sample_df.Start_Lng, y=sample_df.Start_Lat, size=0.001)
# Out:
# <AxesSubplot:xlabel='Start_Lng', ylabel='Start_Lat'>

# %% [markdown]
# # Summary and conclusions

# %% [markdown]
# 1. Less than 5% of cities have more than 1,000 yearly accidents
# 2. States: California has the most accidents
# 3. Streets: I-95 has the most reported accidents
# 4. City: Miami has the most accidents
# 5. Highest percentage of accidents happen between 4 and 6 pm. This is likely because people are leaving work and rushing to get home
# 6. Most accidents occur during the weekdays, with Friday having the most
# 7. December, November and October months have the most accidents
# 8. Weather conditions don't play a major role in frequency of accidents
